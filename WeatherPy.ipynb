# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs=np.random.uniform(low=-180.00,high=180.00, size=1500)
lat_lngs=zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
#Import citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 596

# %%
#Import Dependencies
import requests
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
#Build the basic URL for the OpenWeatherMap
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data=[]
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count=1
set_count=1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list to get URLs.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | narsaq
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | ayr
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | dikson
# Processing Record 7 of Set 1 | tuktoyaktuk
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | zverinogolovskoye
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | snihurivka
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | mumford
# Processing Record 16 of Set 1 | georgetown
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | mahebourg
# Processing Record 19 of Set 1 | necochea
# Processing Record 20 of Set 1 | tahta
# Processing Record 21 of Set 1 | vostok
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | yinchuan
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | iwanai
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | yellowknife
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | wuzhou
# Processing Record 33 of Set 1 | victoria
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 1 | cassilandia
# Processing Record 37 of Set 1 | castro
# Processing Record 38 of Set 1 | shache
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | abu samrah
# Processing Record 42 of Set 1 | vao
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | monticello
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | butaritari
# Processing Record 47 of Set 1 | yarada
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | ayagoz
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | pangnirtung
# Processing Record 3 of Set 2 | celestun
# Processing Record 4 of Set 2 | pascagoula
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | dingle
# Processing Record 7 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 2 | colares
# Processing Record 9 of Set 2 | yulara
# Processing Record 10 of Set 2 | kieta
# Processing Record 11 of Set 2 | hithadhoo
# Processing Record 12 of Set 2 | carnarvon
# Processing Record 13 of Set 2 | dandeli
# Processing Record 14 of Set 2 | nagtipunan
# Processing Record 15 of Set 2 | mehamn
# Processing Record 16 of Set 2 | bambous virieux
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | chuy
# Processing Record 19 of Set 2 | porto san giorgio
# Processing Record 20 of Set 2 | edson
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | alyangula
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | wawa
# Processing Record 25 of Set 2 | ixtapa
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | salalah
# Processing Record 28 of Set 2 | okha
# Processing Record 29 of Set 2 | posse
# Processing Record 30 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 2 | kruisfontein
# Processing Record 32 of Set 2 | new norfolk
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | tortoli
# Processing Record 35 of Set 2 | vila velha
# Processing Record 36 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | nhulunbuy
# Processing Record 39 of Set 2 | mount isa
# Processing Record 40 of Set 2 | isangel
# Processing Record 41 of Set 2 | camacha
# Processing Record 42 of Set 2 | wangdiphodrang
# City not found. Skipping...
# Processing Record 43 of Set 2 | tamale
# Processing Record 44 of Set 2 | aswan
# Processing Record 45 of Set 2 | veraval
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | talnakh
# Processing Record 48 of Set 2 | karratha
# Processing Record 49 of Set 2 | ornskoldsvik
# Processing Record 50 of Set 2 | suriapet
# Processing Record 1 of Set 3 | moron
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | whitehorse
# Processing Record 4 of Set 3 | nanortalik
# Processing Record 5 of Set 3 | sao gabriel da cachoeira
# Processing Record 6 of Set 3 | margate
# Processing Record 7 of Set 3 | sobolevo
# Processing Record 8 of Set 3 | severo-kurilsk
# Processing Record 9 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 10 of Set 3 | smithers
# Processing Record 11 of Set 3 | blagoyevo
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | cape town
# Processing Record 14 of Set 3 | ypsonas
# Processing Record 15 of Set 3 | kodiak
# Processing Record 16 of Set 3 | ambon
# Processing Record 17 of Set 3 | hasaki
# Processing Record 18 of Set 3 | jalu
# Processing Record 19 of Set 3 | buala
# Processing Record 20 of Set 3 | cidreira
# Processing Record 21 of Set 3 | waimana
# Processing Record 22 of Set 3 | rawson
# Processing Record 23 of Set 3 | srednekolymsk
# Processing Record 24 of Set 3 | iqaluit
# Processing Record 25 of Set 3 | conceicao da barra
# Processing Record 26 of Set 3 | katsuura
# Processing Record 27 of Set 3 | beringovskiy
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | bredasdorp
# Processing Record 30 of Set 3 | quatre cocos
# Processing Record 31 of Set 3 | chokurdakh
# Processing Record 32 of Set 3 | san rafael
# Processing Record 33 of Set 3 | tabanan
# Processing Record 34 of Set 3 | cayenne
# Processing Record 35 of Set 3 | leshukonskoye
# Processing Record 36 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 3 | tiarei
# Processing Record 38 of Set 3 | presidencia roque saenz pena
# Processing Record 39 of Set 3 | paamiut
# Processing Record 40 of Set 3 | lavrentiya
# Processing Record 41 of Set 3 | luanda
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | inhambane
# Processing Record 44 of Set 3 | dakoro
# Processing Record 45 of Set 3 | half moon bay
# Processing Record 46 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 47 of Set 3 | marrakesh
# Processing Record 48 of Set 3 | santo domingo
# Processing Record 49 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 4 | mopti
# Processing Record 2 of Set 4 | walvis bay
# Processing Record 3 of Set 4 | coruripe
# Processing Record 4 of Set 4 | namibe
# Processing Record 5 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 4 | olafsvik
# Processing Record 7 of Set 4 | kizukuri
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | pasco
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | hongan
# City not found. Skipping...
# Processing Record 13 of Set 4 | fortuna
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | rio grande
# Processing Record 16 of Set 4 | port augusta
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | waingapu
# Processing Record 19 of Set 4 | aksarka
# Processing Record 20 of Set 4 | havre-saint-pierre
# Processing Record 21 of Set 4 | nuevo ideal
# Processing Record 22 of Set 4 | san mateo ixtatan
# Processing Record 23 of Set 4 | balabac
# Processing Record 24 of Set 4 | sumenep
# Processing Record 25 of Set 4 | port macquarie
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | esperance
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | bonnyville
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | san quintin
# Processing Record 32 of Set 4 | kondol
# Processing Record 33 of Set 4 | east london
# Processing Record 34 of Set 4 | wajid
# Processing Record 35 of Set 4 | cherskiy
# Processing Record 36 of Set 4 | nantucket
# Processing Record 37 of Set 4 | long beach
# Processing Record 38 of Set 4 | samana
# Processing Record 39 of Set 4 | srandakan
# Processing Record 40 of Set 4 | bodden town
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | tomatlan
# Processing Record 43 of Set 4 | tigzirt
# Processing Record 44 of Set 4 | mawlamyine
# Processing Record 45 of Set 4 | batagay
# Processing Record 46 of Set 4 | severomuysk
# Processing Record 47 of Set 4 | cascais
# Processing Record 48 of Set 4 | andrews
# Processing Record 49 of Set 4 | odweyne
# Processing Record 50 of Set 4 | praia da vitoria
# Processing Record 1 of Set 5 | muravlenko
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | beloha
# Processing Record 4 of Set 5 | airai
# Processing Record 5 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 6 of Set 5 | shenjiamen
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | saldanha
# Processing Record 10 of Set 5 | trenggalek
# Processing Record 11 of Set 5 | torbay
# Processing Record 12 of Set 5 | taksimo
# Processing Record 13 of Set 5 | naze
# Processing Record 14 of Set 5 | punta alta
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | coihaique
# Processing Record 17 of Set 5 | ginda
# Processing Record 18 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 5 | ofunato
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | guerrero negro
# Processing Record 22 of Set 5 | karamadai
# Processing Record 23 of Set 5 | nieuwpoort
# Processing Record 24 of Set 5 | tautira
# Processing Record 25 of Set 5 | tadine
# Processing Record 26 of Set 5 | danane
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | mattawa
# Processing Record 29 of Set 5 | mafinga
# Processing Record 30 of Set 5 | pisco
# Processing Record 31 of Set 5 | nikolskoye
# Processing Record 32 of Set 5 | krasnyy chikoy
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | ostrovnoy
# Processing Record 35 of Set 5 | kodinsk
# Processing Record 36 of Set 5 | lorengau
# Processing Record 37 of Set 5 | machali
# Processing Record 38 of Set 5 | baruun-urt
# Processing Record 39 of Set 5 | wewak
# Processing Record 40 of Set 5 | gushikawa
# Processing Record 41 of Set 5 | kamennomostskiy
# Processing Record 42 of Set 5 | belmonte
# Processing Record 43 of Set 5 | monrovia
# Processing Record 44 of Set 5 | pochutla
# Processing Record 45 of Set 5 | verkhnevilyuysk
# Processing Record 46 of Set 5 | taki
# Processing Record 47 of Set 5 | senai
# Processing Record 48 of Set 5 | pak phanang
# Processing Record 49 of Set 5 | qingan
# City not found. Skipping...
# Processing Record 50 of Set 5 | norman wells
# Processing Record 1 of Set 6 | dzilam gonzalez
# Processing Record 2 of Set 6 | kaitangata
# Processing Record 3 of Set 6 | cabedelo
# Processing Record 4 of Set 6 | kitimat
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | eureka
# Processing Record 8 of Set 6 | hirado
# Processing Record 9 of Set 6 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | aklavik
# Processing Record 11 of Set 6 | ariquemes
# Processing Record 12 of Set 6 | alofi
# Processing Record 13 of Set 6 | bilibino
# Processing Record 14 of Set 6 | atar
# Processing Record 15 of Set 6 | broome
# Processing Record 16 of Set 6 | beidao
# Processing Record 17 of Set 6 | newnan
# Processing Record 18 of Set 6 | mitsamiouli
# Processing Record 19 of Set 6 | voznesenye
# Processing Record 20 of Set 6 | george town
# Processing Record 21 of Set 6 | luzhou
# Processing Record 22 of Set 6 | udachnyy
# Processing Record 23 of Set 6 | sao jose da coroa grande
# Processing Record 24 of Set 6 | vestmannaeyjar
# Processing Record 25 of Set 6 | sawakin
# Processing Record 26 of Set 6 | ajdabiya
# Processing Record 27 of Set 6 | nago
# Processing Record 28 of Set 6 | micheweni
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | guichicovi
# City not found. Skipping...
# Processing Record 31 of Set 6 | roald
# Processing Record 32 of Set 6 | fort nelson
# Processing Record 33 of Set 6 | gizo
# Processing Record 34 of Set 6 | saint andrews
# Processing Record 35 of Set 6 | weihai
# Processing Record 36 of Set 6 | bowen
# Processing Record 37 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 38 of Set 6 | pareora
# Processing Record 39 of Set 6 | thompson
# Processing Record 40 of Set 6 | kulachi
# Processing Record 41 of Set 6 | deputatskiy
# Processing Record 42 of Set 6 | simav
# Processing Record 43 of Set 6 | verkhnechusovskiye gorodki
# Processing Record 44 of Set 6 | kochi
# Processing Record 45 of Set 6 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 6 | ilo
# Processing Record 47 of Set 6 | kavieng
# Processing Record 48 of Set 6 | baker city
# Processing Record 49 of Set 6 | riyadh
# Processing Record 50 of Set 6 | caluquembe
# Processing Record 1 of Set 7 | abha
# Processing Record 2 of Set 7 | diffa
# Processing Record 3 of Set 7 | brae
# Processing Record 4 of Set 7 | nurobod
# Processing Record 5 of Set 7 | porbandar
# Processing Record 6 of Set 7 | grindavik
# Processing Record 7 of Set 7 | sayyan
# Processing Record 8 of Set 7 | zhezkazgan
# Processing Record 9 of Set 7 | turbat
# Processing Record 10 of Set 7 | kaeo
# Processing Record 11 of Set 7 | lincoln
# Processing Record 12 of Set 7 | kongolo
# Processing Record 13 of Set 7 | labrea
# Processing Record 14 of Set 7 | bridlington
# Processing Record 15 of Set 7 | waterfoot
# Processing Record 16 of Set 7 | ribeira grande
# Processing Record 17 of Set 7 | sistranda
# Processing Record 18 of Set 7 | mala
# Processing Record 19 of Set 7 | mahanoro
# Processing Record 20 of Set 7 | bonavista
# Processing Record 21 of Set 7 | bilma
# Processing Record 22 of Set 7 | bakau
# Processing Record 23 of Set 7 | kushiro
# Processing Record 24 of Set 7 | qaqortoq
# Processing Record 25 of Set 7 | natchez
# Processing Record 26 of Set 7 | safford
# Processing Record 27 of Set 7 | gladstone
# Processing Record 28 of Set 7 | pahrump
# Processing Record 29 of Set 7 | tamboril
# Processing Record 30 of Set 7 | paragominas
# Processing Record 31 of Set 7 | boa vista
# Processing Record 32 of Set 7 | leningradskiy
# Processing Record 33 of Set 7 | lasa
# Processing Record 34 of Set 7 | rockland
# Processing Record 35 of Set 7 | moyale
# Processing Record 36 of Set 7 | biak
# Processing Record 37 of Set 7 | kelvington
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | burgas
# Processing Record 40 of Set 7 | kargil
# Processing Record 41 of Set 7 | richards bay
# Processing Record 42 of Set 7 | dwarka
# Processing Record 43 of Set 7 | chimbote
# Processing Record 44 of Set 7 | ishigaki
# Processing Record 45 of Set 7 | vardo
# Processing Record 46 of Set 7 | priekule
# Processing Record 47 of Set 7 | olga
# Processing Record 48 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 7 | vulpeni
# Processing Record 50 of Set 7 | klaksvik
# Processing Record 1 of Set 8 | berlevag
# Processing Record 2 of Set 8 | araouane
# Processing Record 3 of Set 8 | guiratinga
# Processing Record 4 of Set 8 | katsina
# Processing Record 5 of Set 8 | nador
# Processing Record 6 of Set 8 | hualmay
# Processing Record 7 of Set 8 | fonte boa
# Processing Record 8 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 8 | nyurba
# Processing Record 10 of Set 8 | flin flon
# Processing Record 11 of Set 8 | qostanay
# Processing Record 12 of Set 8 | tasgaon
# Processing Record 13 of Set 8 | zaragoza
# Processing Record 14 of Set 8 | qasigiannguit
# Processing Record 15 of Set 8 | san cristobal
# Processing Record 16 of Set 8 | kikwit
# Processing Record 17 of Set 8 | carutapera
# Processing Record 18 of Set 8 | oxford
# Processing Record 19 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 8 | mamit
# Processing Record 21 of Set 8 | port blair
# Processing Record 22 of Set 8 | taraz
# Processing Record 23 of Set 8 | novoagansk
# Processing Record 24 of Set 8 | ropczyce
# Processing Record 25 of Set 8 | coahuayana
# Processing Record 26 of Set 8 | havelock
# Processing Record 27 of Set 8 | morwell
# Processing Record 28 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 8 | ust-maya
# Processing Record 30 of Set 8 | jumla
# Processing Record 31 of Set 8 | aviles
# Processing Record 32 of Set 8 | vila franca do campo
# Processing Record 33 of Set 8 | pangkalanbuun
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | nongpoh
# Processing Record 36 of Set 8 | hami
# Processing Record 37 of Set 8 | bathsheba
# Processing Record 38 of Set 8 | santa rosa
# Processing Record 39 of Set 8 | tarata
# Processing Record 40 of Set 8 | stonehaven
# Processing Record 41 of Set 8 | umm lajj
# Processing Record 42 of Set 8 | evora
# Processing Record 43 of Set 8 | dajal
# Processing Record 44 of Set 8 | taupo
# Processing Record 45 of Set 8 | bull savanna
# Processing Record 46 of Set 8 | macenta
# Processing Record 47 of Set 8 | saint anthony
# Processing Record 48 of Set 8 | huarmey
# Processing Record 49 of Set 8 | tessalit
# Processing Record 50 of Set 8 | broken hill
# Processing Record 1 of Set 9 | luwuk
# Processing Record 2 of Set 9 | berkak
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | darnetal
# Processing Record 5 of Set 9 | iracoubo
# Processing Record 6 of Set 9 | yeppoon
# Processing Record 7 of Set 9 | opuwo
# Processing Record 8 of Set 9 | la dolorita
# Processing Record 9 of Set 9 | sambava
# Processing Record 10 of Set 9 | caravelas
# Processing Record 11 of Set 9 | livingston
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | pontianak
# Processing Record 14 of Set 9 | port keats
# Processing Record 15 of Set 9 | along
# Processing Record 16 of Set 9 | el badari
# City not found. Skipping...
# Processing Record 17 of Set 9 | benjamin constant
# Processing Record 18 of Set 9 | scarborough
# Processing Record 19 of Set 9 | lerwick
# Processing Record 20 of Set 9 | conchas
# Processing Record 21 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 9 | tura
# Processing Record 23 of Set 9 | victor harbor
# Processing Record 24 of Set 9 | mucuri
# Processing Record 25 of Set 9 | yazman
# Processing Record 26 of Set 9 | antofagasta
# Processing Record 27 of Set 9 | ordynskoye
# Processing Record 28 of Set 9 | ahuimanu
# Processing Record 29 of Set 9 | shingu
# Processing Record 30 of Set 9 | palaia fokaia
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | dudinka
# Processing Record 33 of Set 9 | okhotsk
# Processing Record 34 of Set 9 | balakliya
# Processing Record 35 of Set 9 | geraldton
# Processing Record 36 of Set 9 | zelenogorskiy
# Processing Record 37 of Set 9 | dicabisagan
# Processing Record 38 of Set 9 | campina verde
# Processing Record 39 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 9 | bonfim
# Processing Record 41 of Set 9 | nishihara
# Processing Record 42 of Set 9 | taywarah
# Processing Record 43 of Set 9 | zhangzhou
# Processing Record 44 of Set 9 | taber
# Processing Record 45 of Set 9 | port hedland
# Processing Record 46 of Set 9 | baykit
# Processing Record 47 of Set 9 | verkhne-katunskoye
# City not found. Skipping...
# Processing Record 48 of Set 9 | lashio
# Processing Record 49 of Set 9 | saint-francois
# Processing Record 50 of Set 9 | dombarovskiy
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | manjacaze
# Processing Record 3 of Set 10 | matamoros
# Processing Record 4 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 10 | sao francisco
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | poum
# Processing Record 8 of Set 10 | chake chake
# Processing Record 9 of Set 10 | falam
# Processing Record 10 of Set 10 | bubaque
# Processing Record 11 of Set 10 | iquitos
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | polyarnyy
# Processing Record 14 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 10 | salekhard
# Processing Record 16 of Set 10 | aberdeen
# Processing Record 17 of Set 10 | mackay
# Processing Record 18 of Set 10 | klamath falls
# Processing Record 19 of Set 10 | termoli
# Processing Record 20 of Set 10 | karatuzskoye
# Processing Record 21 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | las palmas
# Processing Record 23 of Set 10 | liverpool
# Processing Record 24 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 10 | dunedin
# Processing Record 26 of Set 10 | wilmington
# Processing Record 27 of Set 10 | hirara
# Processing Record 28 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 10 | marystown
# Processing Record 30 of Set 10 | bethel
# Processing Record 31 of Set 10 | axim
# Processing Record 32 of Set 10 | cockburn town
# Processing Record 33 of Set 10 | popondetta
# Processing Record 34 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 10 | dubravica
# Processing Record 36 of Set 10 | sopur
# Processing Record 37 of Set 10 | clonakilty
# Processing Record 38 of Set 10 | flinders
# Processing Record 39 of Set 10 | sibu
# Processing Record 40 of Set 10 | xuchang
# Processing Record 41 of Set 10 | hokitika
# Processing Record 42 of Set 10 | hamilton
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | the pas
# Processing Record 45 of Set 10 | yaan
# Processing Record 46 of Set 10 | huanren
# Processing Record 47 of Set 10 | changji
# Processing Record 48 of Set 10 | quballat
# Processing Record 49 of Set 10 | yantal
# Processing Record 50 of Set 10 | mina
# Processing Record 1 of Set 11 | chiredzi
# Processing Record 2 of Set 11 | vaitape
# Processing Record 3 of Set 11 | manta
# Processing Record 4 of Set 11 | catia la mar
# Processing Record 5 of Set 11 | bolivar
# Processing Record 6 of Set 11 | valkla
# Processing Record 7 of Set 11 | ekuvukeni
# Processing Record 8 of Set 11 | touros
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | ampanihy
# Processing Record 11 of Set 11 | mauguio
# Processing Record 12 of Set 11 | namatanai
# Processing Record 13 of Set 11 | russell
# Processing Record 14 of Set 11 | tuatapere
# Processing Record 15 of Set 11 | sao filipe
# Processing Record 16 of Set 11 | hay river
# Processing Record 17 of Set 11 | omsukchan
# Processing Record 18 of Set 11 | jamame
# Processing Record 19 of Set 11 | korla
# Processing Record 20 of Set 11 | lima
# Processing Record 21 of Set 11 | harrai
# Processing Record 22 of Set 11 | naron
# Processing Record 23 of Set 11 | kununurra
# Processing Record 24 of Set 11 | komsomolskiy
# Processing Record 25 of Set 11 | newport
# Processing Record 26 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 11 | guayaramerin
# Processing Record 28 of Set 11 | mildura
# Processing Record 29 of Set 11 | rocha
# Processing Record 30 of Set 11 | port pirie
# Processing Record 31 of Set 11 | sacramento
# Processing Record 32 of Set 11 | kemijarvi
# Processing Record 33 of Set 11 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 11 | almaznyy
# Processing Record 35 of Set 11 | nuristan
# Processing Record 36 of Set 11 | kinangan
# Processing Record 37 of Set 11 | ndele
# Processing Record 38 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 11 | troy
# Processing Record 40 of Set 11 | takoradi
# Processing Record 41 of Set 11 | maceio
# Processing Record 42 of Set 11 | sai buri
# Processing Record 43 of Set 11 | ilulissat
# Processing Record 44 of Set 11 | turukhansk
# Processing Record 45 of Set 11 | zuhres
# Processing Record 46 of Set 11 | kysyl-syr
# Processing Record 47 of Set 11 | ugoofaaru
# Processing Record 48 of Set 11 | ha giang
# Processing Record 49 of Set 11 | chernyy yar
# Processing Record 50 of Set 11 | balagansk
# Processing Record 1 of Set 12 | bardsir
# Processing Record 2 of Set 12 | yian
# City not found. Skipping...
# Processing Record 3 of Set 12 | hobyo
# Processing Record 4 of Set 12 | tabou
# Processing Record 5 of Set 12 | morehead
# Processing Record 6 of Set 12 | muisne
# Processing Record 7 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 8 of Set 12 | solnechnyy
# Processing Record 9 of Set 12 | tarauaca
# Processing Record 10 of Set 12 | matara
# Processing Record 11 of Set 12 | puerto escondido
# Processing Record 12 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 12 | sisimiut
# Processing Record 15 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 16 of Set 12 | mahon
# Processing Record 17 of Set 12 | bundaberg
# Processing Record 18 of Set 12 | ihosy
# Processing Record 19 of Set 12 | acajutla
# Processing Record 20 of Set 12 | ibra
# Processing Record 21 of Set 12 | dembi dolo
# Processing Record 22 of Set 12 | fochville
# Processing Record 23 of Set 12 | kremenki
# Processing Record 24 of Set 12 | aloleng
# Processing Record 25 of Set 12 | novokruchininskiy
# Processing Record 26 of Set 12 | kalmunai
# Processing Record 27 of Set 12 | surt
# Processing Record 28 of Set 12 | kutum
# Processing Record 29 of Set 12 | san jose
# Processing Record 30 of Set 12 | puerto quijarro
# Processing Record 31 of Set 12 | pallisa
# Processing Record 32 of Set 12 | genhe
# Processing Record 33 of Set 12 | farafangana
# Processing Record 34 of Set 12 | severo-yeniseyskiy
# Processing Record 35 of Set 12 | wajima
# Processing Record 36 of Set 12 | khani
# Processing Record 37 of Set 12 | portland
# Processing Record 38 of Set 12 | ucluelet
# Processing Record 39 of Set 12 | maple creek
# Processing Record 40 of Set 12 | novaya igirma
# Processing Record 41 of Set 12 | dauriya
# Processing Record 42 of Set 12 | shirokiy
# Processing Record 43 of Set 12 | ulladulla
# Processing Record 44 of Set 12 | gorin
# Processing Record 45 of Set 12 | port hueneme
# Processing Record 46 of Set 12 | nome
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df=pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Narsaq  60.9167  -46.0500      3.42        66          56        7.92
# 1    Mataura -46.1927  168.8643     58.48        97         100        3.96
# 2        Ayr  55.4627   -4.6339     50.09        93         100       16.11
# 3  Jamestown  42.0970  -79.2353     39.09        63         100        4.00
# 4    Rikitea -23.1203 -134.9692     78.46        73         100        7.78
#
#   Country                 Date
# 0      GL  2022-02-02 22:13:16
# 1      NZ  2022-02-02 22:15:19
# 2      GB  2022-02-02 22:17:47
# 3      US  2022-02-02 22:17:20
# 4      PF  2022-02-02 22:15:29

# %%
#reordering the columns
new_column_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness", "Wind Speed"]
city_data_df=city_data_df[new_column_order]
city_data_df
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Narsaq      GL  2022-02-02 22:13:16  60.9167  -46.0500      3.42
# 1         Mataura      NZ  2022-02-02 22:15:19 -46.1927  168.8643     58.48
# 2             Ayr      GB  2022-02-02 22:17:47  55.4627   -4.6339     50.09
# 3       Jamestown      US  2022-02-02 22:17:20  42.0970  -79.2353     39.09
# 4         Rikitea      PF  2022-02-02 22:15:29 -23.1203 -134.9692     78.46
# ..            ...     ...                  ...      ...       ...       ...
# 545      Shirokiy      RU  2022-02-02 22:27:21  49.7580  129.5230    -23.89
# 546     Ulladulla      AU  2022-02-02 22:31:33 -35.3500  150.4667     66.78
# 547         Gorin      RU  2022-02-02 22:31:33  51.1983  136.6669    -17.05
# 548  Port Hueneme      US  2022-02-02 22:31:33  34.1478 -119.1951     67.78
# 549          Nome      US  2022-02-02 22:29:08  64.5011 -165.4064     10.47
#
#      Humidity  Cloudiness  Wind Speed
# 0          66          56        7.92
# 1          97         100        3.96
# 2          93         100       16.11
# 3          63         100        4.00
# 4          73         100        7.78
# ..        ...         ...         ...
# 545       100          23        4.88
# 546        61          88       13.73
# 547       100          98        1.70
# 548        15           0       23.02
# 549        57           0       35.68
#
# [550 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file="weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats=city_data_df["Lat"]
max_temps=city_data_df["Max Temp"]
humidity=city_data_df["Humidity"]
cloudiness=city_data_df["Cloudiness"]
wind_speed=city_data_df["Wind Speed"]

# %%
#Import Time module
import time

#Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolors="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title("City Latitude vs. Max Temperature " + time.strftime("%x"))
plt.xlabel('Latitude')
plt.ylabel("Max Temperature (F)")
plt.grid()
plt.savefig("weather_data/Fig1.png")

# %%
#Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
           humidity,
           edgecolors="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title("City Latitude vs. Humidity " + time.strftime("%x"))
plt.xlabel('Latitude')
plt.ylabel("Humidity (%)")
plt.grid()

plt.savefig("weather_data/Fig2.png")

# %%
#Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolors="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title("City Latitude vs. Cloudiness " + time.strftime("%x"))
plt.xlabel('Latitude')
plt.ylabel("Cloudiness (%)")
plt.grid()

plt.savefig("weather_data/Fig3.png")

# %%
#Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,
           wind_speed,
           edgecolors="black", linewidths=1, marker="o",
           alpha=0.8, label="Cities")
# Incorporate the other graph properties.
plt.title("City Latitude vs. Wind Speed " + time.strftime("%x"))
plt.xlabel('Latitude')
plt.ylabel("Wind Speed (mph)")
plt.grid()

plt.savefig("weather_data/Fig4.png")

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values,y_values, title, y_label, text_coordinates):
    
   # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err)=linregress(x_values,y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values=x_values*slope+intercept
    
    # Get the equation of the line.
    line_eq = "y= " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regress_values, "r")
    
    #Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13=city_data_df.loc[13]
index13
# Out:
# City                        Vaini
# Country                        TO
# Date          2022-02-02 22:17:49
# Lat                         -21.2
# Lng                        -175.2
# Max Temp                    86.16
# Humidity                       74
# Cloudiness                     40
# Wind Speed                   5.75
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df=city_data_df.loc[(city_data_df["Lat"]>=0)]
southern_hemi_df=city_data_df.loc[(city_data_df["Lat"]<0)]
northern_hemi_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0       Narsaq      GL  2022-02-02 22:13:16  60.9167  -46.0500      3.42
# 2          Ayr      GB  2022-02-02 22:17:47  55.4627   -4.6339     50.09
# 3    Jamestown      US  2022-02-02 22:17:20  42.0970  -79.2353     39.09
# 5       Dikson      RU  2022-02-02 22:17:47  73.5069   80.5464     -7.80
# 6  Tuktoyaktuk      CA  2022-02-02 22:17:47  69.4541 -133.0374    -22.00
#
#    Humidity  Cloudiness  Wind Speed
# 0        66          56        7.92
# 2        93         100       16.11
# 3        63         100        4.00
# 5        98          94        9.89
# 6        76          75       13.80

# %%
# Linear regression on the Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Max Temp"]

#Call the reg function
plot_linear_regression(x_values, y_values,
                      "Linear Regression on the Northern Hemisphere for Maximum Temperature",'Max Temp',(5,-10))

# %%
# Linear regression on the Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Max Temp"]

#call the function

plot_linear_regression(x_values, y_values,'Linear Regression on the Southern Hemisphere for Maximum Temperature', 
                       'Max Temp', (-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Humidity"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Northern Hemisphere for % Humidity",'% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Humidity"]

#call the function
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere for % Humidity",'% Humidity',(-50,15))

# %%
# Linear regression on the Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Cloudiness"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Northern Hemisphere for % Cloudiness",'% Cloudiness',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Cloudiness"]

#call the function
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere for % Cloudiness",'% Cloudiness',(-50,40))

# %%
# Linear regression on the Northern Hemisphere
x_values=northern_hemi_df["Lat"]
y_values=northern_hemi_df["Wind Speed"]

plot_linear_regression(x_values, y_values, "Linear Regression on the Northern Hemisphere for Wind Speed",'Wind Speed (mph)',(40,20))

# %%
# Linear regression on the Southern Hemisphere
x_values=southern_hemi_df["Lat"]
y_values=southern_hemi_df["Wind Speed"]

#call the function
plot_linear_regression(x_values, y_values,"Linear Regression on the Northern Hemisphere for Wind Speed",'Wind Speed (mph)',(-50,15))
