# %% [markdown]
# ## Module 6 Challenge - Deliverable 1

# %%
#Import dependencies
import pandas as pd
import numpy as np
from config import weather_api_key
from citipy import citipy
import requests
import time

# %% [markdown]
# ### Retrieving the Nearest City

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs=np.random.uniform(low=-180.00,high=180.00, size=2000)
lat_lngs=zip(lats,lngs)
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 768

# %% [markdown]
# ### Performing an API Call with the OpenWeatherMap

# %%
#Build the basic URL for the OpenWeatherMap
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data=[]

print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count=1
set_count=1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | uchaly
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | cabo san lucas
# Processing Record 6 of Set 1 | losone
# Processing Record 7 of Set 1 | hithadhoo
# Processing Record 8 of Set 1 | troitsko-pechorsk
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | baykit
# Processing Record 13 of Set 1 | pecos
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | nome
# Processing Record 17 of Set 1 | dunavarsany
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | thaton
# Processing Record 21 of Set 1 | cristalina
# Processing Record 22 of Set 1 | tessalit
# Processing Record 23 of Set 1 | vagur
# Processing Record 24 of Set 1 | half moon bay
# Processing Record 25 of Set 1 | karmana
# City not found. Skipping...
# Processing Record 26 of Set 1 | oga
# Processing Record 27 of Set 1 | san andres
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | walvis bay
# Processing Record 30 of Set 1 | formoso do araguaia
# City not found. Skipping...
# Processing Record 31 of Set 1 | prince rupert
# Processing Record 32 of Set 1 | udachnyy
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | alakurtti
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | parakai
# Processing Record 37 of Set 1 | constitucion
# Processing Record 38 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 1 | garowe
# Processing Record 40 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 1 | svetlogorsk
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | nushki
# Processing Record 45 of Set 1 | longyearbyen
# Processing Record 46 of Set 1 | kampot
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | carnarvon
# Processing Record 49 of Set 1 | hirara
# Processing Record 50 of Set 1 | chicama
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | beringovskiy
# Processing Record 3 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 2 | limbang
# Processing Record 5 of Set 2 | tombouctou
# Processing Record 6 of Set 2 | victoria
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | hermanus
# Processing Record 9 of Set 2 | gull lake
# Processing Record 10 of Set 2 | thompson
# Processing Record 11 of Set 2 | akyab
# Processing Record 12 of Set 2 | sayyan
# Processing Record 13 of Set 2 | pandan
# Processing Record 14 of Set 2 | bilibino
# Processing Record 15 of Set 2 | puerto ayora
# Processing Record 16 of Set 2 | cabedelo
# Processing Record 17 of Set 2 | lat yao
# Processing Record 18 of Set 2 | kodiak
# Processing Record 19 of Set 2 | sistranda
# Processing Record 20 of Set 2 | tigil
# Processing Record 21 of Set 2 | lorengau
# Processing Record 22 of Set 2 | havre-saint-pierre
# Processing Record 23 of Set 2 | rikitea
# Processing Record 24 of Set 2 | huarmey
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | khatanga
# Processing Record 27 of Set 2 | esperance
# Processing Record 28 of Set 2 | koumac
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | rorvik
# Processing Record 31 of Set 2 | new norfolk
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | aden
# Processing Record 34 of Set 2 | aklavik
# Processing Record 35 of Set 2 | yellowknife
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | olafsvik
# Processing Record 38 of Set 2 | geraldton
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | lucea
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | magugu
# Processing Record 43 of Set 2 | pacific grove
# Processing Record 44 of Set 2 | falkoping
# City not found. Skipping...
# Processing Record 45 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | butterworth
# Processing Record 48 of Set 2 | marawi
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | vanimo
# Processing Record 1 of Set 3 | sioux lookout
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | ludhiana
# Processing Record 5 of Set 3 | mvuma
# Processing Record 6 of Set 3 | namibe
# Processing Record 7 of Set 3 | bielawa
# Processing Record 8 of Set 3 | souillac
# Processing Record 9 of Set 3 | shubarkuduk
# Processing Record 10 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 11 of Set 3 | bengkulu
# Processing Record 12 of Set 3 | tilichiki
# Processing Record 13 of Set 3 | kudahuvadhoo
# Processing Record 14 of Set 3 | barranca
# Processing Record 15 of Set 3 | mataura
# Processing Record 16 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 3 | vaasa
# Processing Record 18 of Set 3 | tuensang
# Processing Record 19 of Set 3 | namatanai
# Processing Record 20 of Set 3 | huazhou
# Processing Record 21 of Set 3 | idil
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | itacoatiara
# Processing Record 24 of Set 3 | gazanjyk
# Processing Record 25 of Set 3 | christchurch
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | saint-pierre
# Processing Record 28 of Set 3 | baie-comeau
# Processing Record 29 of Set 3 | korla
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 3 | arawa
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | liku
# Processing Record 36 of Set 3 | paamiut
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | saldanha
# Processing Record 39 of Set 3 | sola
# Processing Record 40 of Set 3 | cape town
# Processing Record 41 of Set 3 | ruthin
# Processing Record 42 of Set 3 | georgetown
# Processing Record 43 of Set 3 | neiafu
# Processing Record 44 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 3 | birobidzhan
# Processing Record 46 of Set 3 | cherskiy
# Processing Record 47 of Set 3 | gravdal
# Processing Record 48 of Set 3 | ambon
# Processing Record 49 of Set 3 | sagar
# Processing Record 50 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 4 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | lampang
# Processing Record 4 of Set 4 | ladario
# Processing Record 5 of Set 4 | turukhansk
# Processing Record 6 of Set 4 | santiago del estero
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | tura
# Processing Record 9 of Set 4 | asau
# Processing Record 10 of Set 4 | vila velha
# Processing Record 11 of Set 4 | calbuco
# Processing Record 12 of Set 4 | barcelona
# Processing Record 13 of Set 4 | dingle
# Processing Record 14 of Set 4 | iqaluit
# Processing Record 15 of Set 4 | clyde river
# Processing Record 16 of Set 4 | bambanglipuro
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 4 | susangerd
# Processing Record 20 of Set 4 | marsh harbour
# Processing Record 21 of Set 4 | narsaq
# Processing Record 22 of Set 4 | havelock
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 25 of Set 4 | davidson
# Processing Record 26 of Set 4 | avera
# Processing Record 27 of Set 4 | bayshore gardens
# Processing Record 28 of Set 4 | chokurdakh
# Processing Record 29 of Set 4 | belmonte
# Processing Record 30 of Set 4 | lagoa
# Processing Record 31 of Set 4 | betioky
# Processing Record 32 of Set 4 | lugovskiy
# City not found. Skipping...
# Processing Record 33 of Set 4 | mudgee
# Processing Record 34 of Set 4 | ponta do sol
# Processing Record 35 of Set 4 | safranbolu
# Processing Record 36 of Set 4 | tinskoy
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | katherine
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | corinto
# Processing Record 41 of Set 4 | igurusi
# Processing Record 42 of Set 4 | byron bay
# Processing Record 43 of Set 4 | kilindoni
# Processing Record 44 of Set 4 | radhanpur
# Processing Record 45 of Set 4 | mahanoro
# Processing Record 46 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 4 | iquique
# Processing Record 48 of Set 4 | banda aceh
# Processing Record 49 of Set 4 | grand gaube
# Processing Record 50 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 1 of Set 5 | kununurra
# Processing Record 2 of Set 5 | atambua
# Processing Record 3 of Set 5 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 5 | soe
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | kremenki
# Processing Record 7 of Set 5 | beihai
# Processing Record 8 of Set 5 | chihuahua
# Processing Record 9 of Set 5 | bonthe
# Processing Record 10 of Set 5 | fare
# Processing Record 11 of Set 5 | yeppoon
# Processing Record 12 of Set 5 | jacareacanga
# Processing Record 13 of Set 5 | champerico
# Processing Record 14 of Set 5 | gedo
# Processing Record 15 of Set 5 | tumen
# Processing Record 16 of Set 5 | naze
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 5 | balad
# Processing Record 20 of Set 5 | mokobeng
# Processing Record 21 of Set 5 | nevsehir
# Processing Record 22 of Set 5 | necochea
# Processing Record 23 of Set 5 | ornskoldsvik
# Processing Record 24 of Set 5 | kavieng
# Processing Record 25 of Set 5 | lons-le-saunier
# Processing Record 26 of Set 5 | senador pompeu
# Processing Record 27 of Set 5 | guerrero negro
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | barabinsk
# Processing Record 30 of Set 5 | boo
# Processing Record 31 of Set 5 | tiksi
# Processing Record 32 of Set 5 | praia da vitoria
# Processing Record 33 of Set 5 | marfino
# Processing Record 34 of Set 5 | tanout
# Processing Record 35 of Set 5 | saint-raphael
# Processing Record 36 of Set 5 | roebourne
# Processing Record 37 of Set 5 | fort nelson
# Processing Record 38 of Set 5 | cedar city
# Processing Record 39 of Set 5 | saskylakh
# Processing Record 40 of Set 5 | ibanesti
# Processing Record 41 of Set 5 | sabha
# Processing Record 42 of Set 5 | baoro
# Processing Record 43 of Set 5 | labuan
# Processing Record 44 of Set 5 | camacha
# Processing Record 45 of Set 5 | mount gambier
# Processing Record 46 of Set 5 | boyolangu
# Processing Record 47 of Set 5 | abnub
# Processing Record 48 of Set 5 | gewane
# Processing Record 49 of Set 5 | pout
# Processing Record 50 of Set 5 | acapulco
# Processing Record 1 of Set 6 | ituiutaba
# Processing Record 2 of Set 6 | ritchie
# Processing Record 3 of Set 6 | maningrida
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | benemerito de las americas
# Processing Record 6 of Set 6 | nanortalik
# Processing Record 7 of Set 6 | dudinka
# Processing Record 8 of Set 6 | sungaipenuh
# Processing Record 9 of Set 6 | anzio
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | bollnas
# Processing Record 12 of Set 6 | valparaiso
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | mamaku
# Processing Record 15 of Set 6 | ratnagiri
# Processing Record 16 of Set 6 | san jose
# Processing Record 17 of Set 6 | celestun
# Processing Record 18 of Set 6 | dikson
# Processing Record 19 of Set 6 | shumikha
# Processing Record 20 of Set 6 | kapustin yar-1
# City not found. Skipping...
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 23 of Set 6 | gizo
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | phan thiet
# Processing Record 26 of Set 6 | svetlaya
# Processing Record 27 of Set 6 | belaya gora
# Processing Record 28 of Set 6 | tigbao
# Processing Record 29 of Set 6 | voyvozh
# Processing Record 30 of Set 6 | mount isa
# Processing Record 31 of Set 6 | alofi
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 6 | puerto escondido
# Processing Record 35 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 6 | beloha
# Processing Record 37 of Set 6 | mogadouro
# Processing Record 38 of Set 6 | vestmannaeyjar
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | vila franca do campo
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | deputatskiy
# Processing Record 43 of Set 6 | port hedland
# Processing Record 44 of Set 6 | bambous virieux
# Processing Record 45 of Set 6 | karratha
# Processing Record 46 of Set 6 | sao joao da barra
# Processing Record 47 of Set 6 | acarau
# Processing Record 48 of Set 6 | oakdale
# Processing Record 49 of Set 6 | teya
# Processing Record 50 of Set 6 | farmington
# Processing Record 1 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 7 | ekhabi
# Processing Record 3 of Set 7 | greenfield
# Processing Record 4 of Set 7 | nuevo progreso
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | caravelas
# Processing Record 7 of Set 7 | sri aman
# Processing Record 8 of Set 7 | concepcion de maria
# City not found. Skipping...
# Processing Record 9 of Set 7 | nouadhibou
# Processing Record 10 of Set 7 | kassala
# Processing Record 11 of Set 7 | kamaishi
# Processing Record 12 of Set 7 | aves
# Processing Record 13 of Set 7 | kurumkan
# Processing Record 14 of Set 7 | la ciotat
# Processing Record 15 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 7 | pangnirtung
# Processing Record 17 of Set 7 | sarkand
# Processing Record 18 of Set 7 | ito
# Processing Record 19 of Set 7 | fortuna
# Processing Record 20 of Set 7 | honiara
# Processing Record 21 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 7 | puerto cabezas
# Processing Record 23 of Set 7 | yulara
# Processing Record 24 of Set 7 | jizan
# Processing Record 25 of Set 7 | bathsheba
# Processing Record 26 of Set 7 | trairi
# Processing Record 27 of Set 7 | vila
# Processing Record 28 of Set 7 | kaitangata
# Processing Record 29 of Set 7 | toora-khem
# Processing Record 30 of Set 7 | fairbanks
# Processing Record 31 of Set 7 | broome
# Processing Record 32 of Set 7 | upernavik
# Processing Record 33 of Set 7 | kitimat
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | lukovetskiy
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | ylivieska
# Processing Record 38 of Set 7 | ostrovnoy
# Processing Record 39 of Set 7 | nikolskoye
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | port hardy
# Processing Record 42 of Set 7 | sovetskiy
# Processing Record 43 of Set 7 | japura
# Processing Record 44 of Set 7 | drayton valley
# Processing Record 45 of Set 7 | ayoquezco
# City not found. Skipping...
# Processing Record 46 of Set 7 | champawat
# Processing Record 47 of Set 7 | porto novo
# Processing Record 48 of Set 7 | berbera
# Processing Record 49 of Set 7 | oistins
# Processing Record 50 of Set 7 | moussoro
# Processing Record 1 of Set 8 | tual
# Processing Record 2 of Set 8 | saint-augustin
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | anadyr
# Processing Record 5 of Set 8 | abdanan
# Processing Record 6 of Set 8 | adana
# Processing Record 7 of Set 8 | yirol
# City not found. Skipping...
# Processing Record 8 of Set 8 | maceio
# Processing Record 9 of Set 8 | kismayo
# Processing Record 10 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 11 of Set 8 | werda
# Processing Record 12 of Set 8 | adrar
# Processing Record 13 of Set 8 | shache
# Processing Record 14 of Set 8 | comodoro rivadavia
# Processing Record 15 of Set 8 | bulgan
# Processing Record 16 of Set 8 | san quintin
# Processing Record 17 of Set 8 | tarifa
# Processing Record 18 of Set 8 | bereda
# Processing Record 19 of Set 8 | norfolk
# Processing Record 20 of Set 8 | cumana
# Processing Record 21 of Set 8 | waipawa
# Processing Record 22 of Set 8 | marica
# Processing Record 23 of Set 8 | yakeshi
# Processing Record 24 of Set 8 | krk
# Processing Record 25 of Set 8 | lebu
# Processing Record 26 of Set 8 | milledgeville
# Processing Record 27 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 28 of Set 8 | hualmay
# Processing Record 29 of Set 8 | jamame
# Processing Record 30 of Set 8 | klaksvik
# Processing Record 31 of Set 8 | ashington
# Processing Record 32 of Set 8 | saint anthony
# Processing Record 33 of Set 8 | mwinilunga
# Processing Record 34 of Set 8 | hambantota
# Processing Record 35 of Set 8 | plymouth
# Processing Record 36 of Set 8 | awbari
# Processing Record 37 of Set 8 | krasnoarmeysk
# Processing Record 38 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 39 of Set 8 | saint-georges
# Processing Record 40 of Set 8 | bud
# Processing Record 41 of Set 8 | gaillac
# Processing Record 42 of Set 8 | poum
# Processing Record 43 of Set 8 | stornoway
# Processing Record 44 of Set 8 | xuddur
# Processing Record 45 of Set 8 | batagay
# Processing Record 46 of Set 8 | tomatlan
# Processing Record 47 of Set 8 | kharitonovo
# Processing Record 48 of Set 8 | beira
# Processing Record 49 of Set 8 | hovd
# Processing Record 50 of Set 8 | isangel
# Processing Record 1 of Set 9 | chaplynka
# Processing Record 2 of Set 9 | lakatoro
# Processing Record 3 of Set 9 | marystown
# Processing Record 4 of Set 9 | sawtell
# Processing Record 5 of Set 9 | leningradskiy
# Processing Record 6 of Set 9 | gigmoto
# Processing Record 7 of Set 9 | key west
# Processing Record 8 of Set 9 | cockburn town
# Processing Record 9 of Set 9 | lagos
# Processing Record 10 of Set 9 | lasa
# Processing Record 11 of Set 9 | sobreira
# Processing Record 12 of Set 9 | labuhan
# Processing Record 13 of Set 9 | sakakah
# Processing Record 14 of Set 9 | bolshaya atnya
# City not found. Skipping...
# Processing Record 15 of Set 9 | houma
# Processing Record 16 of Set 9 | dubno
# Processing Record 17 of Set 9 | flinders
# Processing Record 18 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | terrace bay
# Processing Record 21 of Set 9 | laem sing
# Processing Record 22 of Set 9 | revelstoke
# Processing Record 23 of Set 9 | slave lake
# Processing Record 24 of Set 9 | lavrentiya
# Processing Record 25 of Set 9 | bongandanga
# Processing Record 26 of Set 9 | te anau
# Processing Record 27 of Set 9 | teodoro sampaio
# Processing Record 28 of Set 9 | pangkalanbuun
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | hobyo
# Processing Record 31 of Set 9 | padang
# Processing Record 32 of Set 9 | erzin
# Processing Record 33 of Set 9 | eyemouth
# Processing Record 34 of Set 9 | magnolia
# Processing Record 35 of Set 9 | tiarei
# Processing Record 36 of Set 9 | charters towers
# Processing Record 37 of Set 9 | zelenoborsk
# Processing Record 38 of Set 9 | stromness
# Processing Record 39 of Set 9 | high rock
# Processing Record 40 of Set 9 | zhangjiakou
# Processing Record 41 of Set 9 | severo-yeniseyskiy
# Processing Record 42 of Set 9 | lieksa
# Processing Record 43 of Set 9 | krasnyy chikoy
# Processing Record 44 of Set 9 | gushikawa
# Processing Record 45 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 46 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | machachi
# Processing Record 49 of Set 9 | hammerfest
# Processing Record 50 of Set 9 | alta floresta
# Processing Record 1 of Set 10 | mathathane
# Processing Record 2 of Set 10 | puerto maldonado
# Processing Record 3 of Set 10 | chuy
# Processing Record 4 of Set 10 | ketchikan
# Processing Record 5 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 6 of Set 10 | orotukan
# Processing Record 7 of Set 10 | roros
# Processing Record 8 of Set 10 | kjollefjord
# Processing Record 9 of Set 10 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 10 | teguldet
# Processing Record 11 of Set 10 | mahibadhoo
# Processing Record 12 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 10 | nelson bay
# Processing Record 14 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 10 | sorland
# Processing Record 16 of Set 10 | san patricio
# Processing Record 17 of Set 10 | iralaya
# Processing Record 18 of Set 10 | yumen
# Processing Record 19 of Set 10 | carmo do paranaiba
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | sitka
# Processing Record 22 of Set 10 | bemidji
# Processing Record 23 of Set 10 | jalu
# Processing Record 24 of Set 10 | nkwerre
# Processing Record 25 of Set 10 | katsuura
# Processing Record 26 of Set 10 | venice
# Processing Record 27 of Set 10 | kholodnyy
# Processing Record 28 of Set 10 | danielskuil
# Processing Record 29 of Set 10 | bergama
# Processing Record 30 of Set 10 | kainantu
# Processing Record 31 of Set 10 | prince albert
# Processing Record 32 of Set 10 | novikovo
# Processing Record 33 of Set 10 | shumskiy
# Processing Record 34 of Set 10 | bilma
# Processing Record 35 of Set 10 | tila
# Processing Record 36 of Set 10 | esil
# Processing Record 37 of Set 10 | sechura
# Processing Record 38 of Set 10 | saint george
# Processing Record 39 of Set 10 | gat
# Processing Record 40 of Set 10 | tuy hoa
# Processing Record 41 of Set 10 | verkhneyarkeyevo
# Processing Record 42 of Set 10 | rio gallegos
# Processing Record 43 of Set 10 | altay
# Processing Record 44 of Set 10 | kozluk
# Processing Record 45 of Set 10 | shankargarh
# Processing Record 46 of Set 10 | salalah
# Processing Record 47 of Set 10 | yuncheng
# Processing Record 48 of Set 10 | kosino
# Processing Record 49 of Set 10 | la grande
# Processing Record 50 of Set 10 | general roca
# Processing Record 1 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 11 | rudbar
# Processing Record 3 of Set 11 | sobolevo
# Processing Record 4 of Set 11 | juegang
# Processing Record 5 of Set 11 | nauta
# Processing Record 6 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 11 | polunochnoye
# Processing Record 8 of Set 11 | kamina
# Processing Record 9 of Set 11 | bull savanna
# Processing Record 10 of Set 11 | shellbrook
# Processing Record 11 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 11 | quatre cocos
# Processing Record 13 of Set 11 | antequera
# Processing Record 14 of Set 11 | botngard
# Processing Record 15 of Set 11 | pedernales
# Processing Record 16 of Set 11 | taltal
# Processing Record 17 of Set 11 | san policarpo
# Processing Record 18 of Set 11 | pochutla
# Processing Record 19 of Set 11 | graaff-reinet
# Processing Record 20 of Set 11 | woodstock
# Processing Record 21 of Set 11 | abadiania
# Processing Record 22 of Set 11 | baikunthpur
# Processing Record 23 of Set 11 | honningsvag
# Processing Record 24 of Set 11 | boromo
# Processing Record 25 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 11 | san pedro
# Processing Record 27 of Set 11 | malakal
# Processing Record 28 of Set 11 | totness
# Processing Record 29 of Set 11 | emerald
# Processing Record 30 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 11 | channel-port aux basques
# Processing Record 32 of Set 11 | alekseyevsk
# Processing Record 33 of Set 11 | marzuq
# Processing Record 34 of Set 11 | mumbwa
# Processing Record 35 of Set 11 | allen
# Processing Record 36 of Set 11 | davila
# Processing Record 37 of Set 11 | stephenville
# Processing Record 38 of Set 11 | bindura
# Processing Record 39 of Set 11 | mut
# Processing Record 40 of Set 11 | lebyazhye
# Processing Record 41 of Set 11 | bezhetsk
# Processing Record 42 of Set 11 | diamantino
# Processing Record 43 of Set 11 | general artigas
# Processing Record 44 of Set 11 | sosnovo
# Processing Record 45 of Set 11 | berlevag
# Processing Record 46 of Set 11 | boende
# Processing Record 47 of Set 11 | castlemaine
# Processing Record 48 of Set 11 | gamba
# Processing Record 49 of Set 11 | crotone
# Processing Record 50 of Set 11 | bundaberg
# Processing Record 1 of Set 12 | douglas
# Processing Record 2 of Set 12 | rindal
# Processing Record 3 of Set 12 | ardahan
# Processing Record 4 of Set 12 | tosagua
# Processing Record 5 of Set 12 | biak
# Processing Record 6 of Set 12 | westport
# Processing Record 7 of Set 12 | ixtapa
# Processing Record 8 of Set 12 | inuvik
# Processing Record 9 of Set 12 | karasburg
# Processing Record 10 of Set 12 | akureyri
# Processing Record 11 of Set 12 | tres picos
# Processing Record 12 of Set 12 | komsomolskiy
# Processing Record 13 of Set 12 | erken-shakhar
# City not found. Skipping...
# Processing Record 14 of Set 12 | bentiu
# Processing Record 15 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 16 of Set 12 | alice springs
# Processing Record 17 of Set 12 | okhotsk
# Processing Record 18 of Set 12 | santa cruz
# Processing Record 19 of Set 12 | coronel mariduena
# City not found. Skipping...
# Processing Record 20 of Set 12 | palmer
# Processing Record 21 of Set 12 | posadas
# Processing Record 22 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 23 of Set 12 | cuamba
# Processing Record 24 of Set 12 | port elizabeth
# Processing Record 25 of Set 12 | pahrump
# Processing Record 26 of Set 12 | codrington
# Processing Record 27 of Set 12 | maniitsoq
# Processing Record 28 of Set 12 | tuatapere
# Processing Record 29 of Set 12 | sumber
# Processing Record 30 of Set 12 | yunyang
# Processing Record 31 of Set 12 | nanakuli
# Processing Record 32 of Set 12 | meadow lake
# Processing Record 33 of Set 12 | kibara
# Processing Record 34 of Set 12 | saint-joseph
# Processing Record 35 of Set 12 | severnyy
# Processing Record 36 of Set 12 | kortkeros
# Processing Record 37 of Set 12 | collie
# Processing Record 38 of Set 12 | van wert
# Processing Record 39 of Set 12 | guaruja
# Processing Record 40 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 41 of Set 12 | makakilo city
# Processing Record 42 of Set 12 | tarakan
# Processing Record 43 of Set 12 | cartagena
# Processing Record 44 of Set 12 | sucre
# Processing Record 45 of Set 12 | tecolutla
# Processing Record 46 of Set 12 | griffith
# Processing Record 47 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 48 of Set 12 | wasilla
# Processing Record 49 of Set 12 | masindi
# Processing Record 50 of Set 12 | margate
# Processing Record 1 of Set 13 | orodara
# Processing Record 2 of Set 13 | aswan
# Processing Record 3 of Set 13 | bedele
# Processing Record 4 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 13 | purificacion
# Processing Record 6 of Set 13 | masuda
# Processing Record 7 of Set 13 | canchungo
# Processing Record 8 of Set 13 | madimba
# Processing Record 9 of Set 13 | kutum
# Processing Record 10 of Set 13 | williston
# Processing Record 11 of Set 13 | menongue
# Processing Record 12 of Set 13 | berdigestyakh
# Processing Record 13 of Set 13 | oranjemund
# Processing Record 14 of Set 13 | bara
# Processing Record 15 of Set 13 | otane
# Processing Record 16 of Set 13 | suntar
# Processing Record 17 of Set 13 | meru
# Processing Record 18 of Set 13 | chutove
# Processing Record 19 of Set 13 | vanavara
# Processing Record 20 of Set 13 | tamworth
# Processing Record 21 of Set 13 | dharur
# Processing Record 22 of Set 13 | affery
# Processing Record 23 of Set 13 | pangody
# Processing Record 24 of Set 13 | ledziny
# Processing Record 25 of Set 13 | los llanos de aridane
# Processing Record 26 of Set 13 | siguiri
# Processing Record 27 of Set 13 | nouakchott
# Processing Record 28 of Set 13 | husavik
# Processing Record 29 of Set 13 | taunggyi
# Processing Record 30 of Set 13 | krosno
# Processing Record 31 of Set 13 | touros
# Processing Record 32 of Set 13 | cap malheureux
# Processing Record 33 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 34 of Set 13 | vostok
# Processing Record 35 of Set 13 | kokkola
# Processing Record 36 of Set 13 | dibaya
# City not found. Skipping...
# Processing Record 37 of Set 13 | cap-aux-meules
# Processing Record 38 of Set 13 | katobu
# Processing Record 39 of Set 13 | tahara
# Processing Record 40 of Set 13 | kuala terengganu
# Processing Record 41 of Set 13 | nanyang
# Processing Record 42 of Set 13 | mawlaik
# Processing Record 43 of Set 13 | la ronge
# Processing Record 44 of Set 13 | shubarshi
# Processing Record 45 of Set 13 | itaueira
# Processing Record 46 of Set 13 | kungurtug
# Processing Record 47 of Set 13 | riyadh
# Processing Record 48 of Set 13 | morros
# Processing Record 49 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 50 of Set 13 | selikhino
# Processing Record 1 of Set 14 | kanigoro
# Processing Record 2 of Set 14 | kahului
# Processing Record 3 of Set 14 | biograd na moru
# Processing Record 4 of Set 14 | cooma
# Processing Record 5 of Set 14 | pangoa
# Processing Record 6 of Set 14 | faya
# Processing Record 7 of Set 14 | camacupa
# Processing Record 8 of Set 14 | fukuma
# Processing Record 9 of Set 14 | aykhal
# Processing Record 10 of Set 14 | darhan
# Processing Record 11 of Set 14 | fuerte olimpo
# Processing Record 12 of Set 14 | shu
# Processing Record 13 of Set 14 | solnechnyy
# Processing Record 14 of Set 14 | boguchany
# Processing Record 15 of Set 14 | ellisras
# Processing Record 16 of Set 14 | waingapu
# Processing Record 17 of Set 14 | zima
# Processing Record 18 of Set 14 | minab
# Processing Record 19 of Set 14 | kenai
# Processing Record 20 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 21 of Set 14 | apac
# Processing Record 22 of Set 14 | okha
# Processing Record 23 of Set 14 | bafq
# Processing Record 24 of Set 14 | antalaha
# Processing Record 25 of Set 14 | boissevain
# Processing Record 26 of Set 14 | xunchang
# Processing Record 27 of Set 14 | mecca
# Processing Record 28 of Set 14 | kamenka
# Processing Record 29 of Set 14 | magan
# Processing Record 30 of Set 14 | xifeng
# Processing Record 31 of Set 14 | muriwai beach
# Processing Record 32 of Set 14 | subang
# Processing Record 33 of Set 14 | sept-iles
# Processing Record 34 of Set 14 | golyshmanovo
# Processing Record 35 of Set 14 | brits
# Processing Record 36 of Set 14 | itarema
# Processing Record 37 of Set 14 | boyabat
# Processing Record 38 of Set 14 | skjold
# Processing Record 39 of Set 14 | viedma
# Processing Record 40 of Set 14 | turbat
# Processing Record 41 of Set 14 | yei
# Processing Record 42 of Set 14 | cabra
# Processing Record 43 of Set 14 | ahuimanu
# Processing Record 44 of Set 14 | presidencia roque saenz pena
# Processing Record 45 of Set 14 | mwingi
# Processing Record 46 of Set 14 | airai
# Processing Record 47 of Set 14 | nueve de julio
# Processing Record 48 of Set 14 | hengyang
# Processing Record 49 of Set 14 | juneau
# Processing Record 50 of Set 14 | sao geraldo do araguaia
# Processing Record 1 of Set 15 | provideniya
# Processing Record 2 of Set 15 | leshukonskoye
# Processing Record 3 of Set 15 | liverpool
# Processing Record 4 of Set 15 | meulaboh
# Processing Record 5 of Set 15 | mnogovershinnyy
# Processing Record 6 of Set 15 | kodino
# Processing Record 7 of Set 15 | fez
# Processing Record 8 of Set 15 | shimoda
# Processing Record 9 of Set 15 | minyar
# Processing Record 10 of Set 15 | bogorodskoye
# Processing Record 11 of Set 15 | grindavik
# Processing Record 12 of Set 15 | lima
# Processing Record 13 of Set 15 | bastrop
# Processing Record 14 of Set 15 | amahai
# Processing Record 15 of Set 15 | mabaruma
# Processing Record 16 of Set 15 | gaoual
# Processing Record 17 of Set 15 | tubuala
# Processing Record 18 of Set 15 | nenjiang
# Processing Record 19 of Set 15 | taytay
# Processing Record 20 of Set 15 | port augusta
# Processing Record 21 of Set 15 | talagang
# Processing Record 22 of Set 15 | freeport
# Processing Record 23 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 15 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 15 | malkangiri
# Processing Record 26 of Set 15 | tevaitoa
# Processing Record 27 of Set 15 | odesskoye
# Processing Record 28 of Set 15 | kosh-agach
# Processing Record 29 of Set 15 | mundo nuevo
# Processing Record 30 of Set 15 | ewa beach
# Processing Record 31 of Set 15 | nha trang
# Processing Record 32 of Set 15 | pitimbu
# Processing Record 33 of Set 15 | ghanzi
# Processing Record 34 of Set 15 | mayor pablo lagerenza
# Processing Record 35 of Set 15 | joshimath
# Processing Record 36 of Set 15 | vavuniya
# Processing Record 37 of Set 15 | havoysund
# Processing Record 38 of Set 15 | visby
# Processing Record 39 of Set 15 | saint-felicien
# Processing Record 40 of Set 15 | pemangkat
# Processing Record 41 of Set 15 | yarmouth
# Processing Record 42 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 44 of Set 15 | sabang
# Processing Record 45 of Set 15 | zhezkazgan
# Processing Record 46 of Set 15 | porto seguro
# Processing Record 47 of Set 15 | le port
# Processing Record 48 of Set 15 | nemuro
# Processing Record 49 of Set 15 | aldan
# Processing Record 50 of Set 15 | maneadero
# Processing Record 1 of Set 16 | kerman
# Processing Record 2 of Set 16 | kegayli
# City not found. Skipping...
# Processing Record 3 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 4 of Set 16 | carutapera
# Processing Record 5 of Set 16 | kabinda
# Processing Record 6 of Set 16 | esperantinopolis
# Processing Record 7 of Set 16 | paracuru
# Processing Record 8 of Set 16 | burayevo
# Processing Record 9 of Set 16 | ulaanbaatar
# Processing Record 10 of Set 16 | wewak
# Processing Record 11 of Set 16 | ranong
# Processing Record 12 of Set 16 | burica
# City not found. Skipping...
# Processing Record 13 of Set 16 | laramie
# Processing Record 14 of Set 16 | sorong
# Processing Record 15 of Set 16 | loudi
# Processing Record 16 of Set 16 | cayenne
# Processing Record 17 of Set 16 | bandarbeyla
# Processing Record 18 of Set 16 | lavumisa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
#Adding the data to a new DataFrame
weatherpy_df=pd.DataFrame(city_data)
weatherpy_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Uchaly      RU  54.2996   59.4521     15.06        95         100
# 1          Albany      US  42.6001  -73.9662     26.91        87         100
# 2     Port Alfred      ZA -33.5906   26.8910     68.16        80         100
# 3         Ushuaia      AR -54.8000  -68.3000     62.91        41          33
# 4  Cabo San Lucas      MX  22.8909 -109.9124     74.52        48           0
#
#    Wind Speed Current Description
# 0        4.14     overcast clouds
# 1        6.33          light snow
# 2        7.52          light rain
# 3        2.42    scattered clouds
# 4        8.05           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
weatherpy_df.to_csv(output_data_file, index_label='City_ID')
