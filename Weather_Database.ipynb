# %% [markdown]
# ## Module 6 Challenge - Deliverable 1

# %%
#Import dependencies
import pandas as pd
import numpy as np
from config import weather_api_key
from citipy import citipy
import requests
import time

# %% [markdown]
# ### Retrieving the Nearest City

# %%
# Create a set of random latitude and longitude combinations.
lats=np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs=np.random.uniform(low=-180.00,high=180.00, size=2000)
lat_lngs=zip(lats,lngs)
# Add the latitudes and longitudes to a list.
coordinates=list(lat_lngs)

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city=citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 741

# %% [markdown]
# ### Performing an API Call with the OpenWeatherMap

# %%
#Build the basic URL for the OpenWeatherMap
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data=[]

print("Beginning Data Retrieval     ")
print("-----------------------------")

#create counters
record_count=1
set_count=1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]['description']

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | jacareacanga
# Processing Record 5 of Set 1 | vanavara
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 1 | alofi
# Processing Record 9 of Set 1 | iqaluit
# Processing Record 10 of Set 1 | tessalit
# Processing Record 11 of Set 1 | zalantun
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | catamarca
# Processing Record 14 of Set 1 | kieta
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | broome
# Processing Record 19 of Set 1 | elizabeth city
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | puerto colombia
# Processing Record 24 of Set 1 | guarumal
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | lata
# Processing Record 28 of Set 1 | tilichiki
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | kavaratti
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | pevek
# Processing Record 34 of Set 1 | provideniya
# Processing Record 35 of Set 1 | vila franca do campo
# Processing Record 36 of Set 1 | upernavik
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | pemberton
# Processing Record 39 of Set 1 | saint-leu
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | jumla
# Processing Record 43 of Set 1 | ahipara
# Processing Record 44 of Set 1 | tayoltita
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | atar
# Processing Record 48 of Set 1 | thompson
# Processing Record 49 of Set 1 | pisco
# Processing Record 50 of Set 1 | atuona
# Processing Record 1 of Set 2 | griffith
# Processing Record 2 of Set 2 | santo domingo
# Processing Record 3 of Set 2 | belozerskoye
# Processing Record 4 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | port lincoln
# Processing Record 9 of Set 2 | salalah
# Processing Record 10 of Set 2 | lvov
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | barao de melgaco
# Processing Record 13 of Set 2 | otjimbingwe
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | kulhudhuffushi
# Processing Record 16 of Set 2 | fairbanks
# Processing Record 17 of Set 2 | zhigansk
# Processing Record 18 of Set 2 | mitsamiouli
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 2 | nikolskoye
# Processing Record 22 of Set 2 | grand baie
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | san quintin
# Processing Record 25 of Set 2 | saint-donat-de-montcalm
# Processing Record 26 of Set 2 | deputatskiy
# Processing Record 27 of Set 2 | beruni
# City not found. Skipping...
# Processing Record 28 of Set 2 | bluff
# Processing Record 29 of Set 2 | inuvik
# Processing Record 30 of Set 2 | singaraja
# Processing Record 31 of Set 2 | rodrigues alves
# Processing Record 32 of Set 2 | esperance
# Processing Record 33 of Set 2 | monor
# Processing Record 34 of Set 2 | kirakira
# Processing Record 35 of Set 2 | havelock
# Processing Record 36 of Set 2 | rio grande
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | fortuna
# Processing Record 39 of Set 2 | andenes
# Processing Record 40 of Set 2 | ponta do sol
# Processing Record 41 of Set 2 | puri
# Processing Record 42 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 2 | mezen
# Processing Record 44 of Set 2 | albany
# Processing Record 45 of Set 2 | bourail
# Processing Record 46 of Set 2 | cherskiy
# Processing Record 47 of Set 2 | torbay
# Processing Record 48 of Set 2 | port alfred
# Processing Record 49 of Set 2 | new norfolk
# Processing Record 50 of Set 2 | berlevag
# Processing Record 1 of Set 3 | farafangana
# Processing Record 2 of Set 3 | itupiranga
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | lagoa
# Processing Record 5 of Set 3 | dalvik
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | leh
# Processing Record 8 of Set 3 | pasan
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | sorland
# Processing Record 11 of Set 3 | hilo
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | kaitangata
# Processing Record 16 of Set 3 | saint george
# Processing Record 17 of Set 3 | kapaa
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 3 | ribeira grande
# Processing Record 22 of Set 3 | bihariganj
# Processing Record 23 of Set 3 | zaysan
# Processing Record 24 of Set 3 | shubarkuduk
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | bilma
# Processing Record 27 of Set 3 | cabo san lucas
# Processing Record 28 of Set 3 | vernon
# Processing Record 29 of Set 3 | hobyo
# Processing Record 30 of Set 3 | lashio
# Processing Record 31 of Set 3 | odda
# Processing Record 32 of Set 3 | bredasdorp
# Processing Record 33 of Set 3 | cape town
# Processing Record 34 of Set 3 | ixtapa
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | huejuquilla el alto
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | kenai
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | joniskelis
# Processing Record 42 of Set 3 | nadvoitsy
# Processing Record 43 of Set 3 | haines junction
# Processing Record 44 of Set 3 | namatanai
# Processing Record 45 of Set 3 | fairview
# Processing Record 46 of Set 3 | evensk
# Processing Record 47 of Set 3 | virtsu
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | jinchang
# Processing Record 50 of Set 3 | talnakh
# Processing Record 1 of Set 4 | eureka
# Processing Record 2 of Set 4 | latung
# Processing Record 3 of Set 4 | urdoma
# Processing Record 4 of Set 4 | mungwi
# Processing Record 5 of Set 4 | aswan
# Processing Record 6 of Set 4 | east london
# Processing Record 7 of Set 4 | vostok
# Processing Record 8 of Set 4 | kimbe
# Processing Record 9 of Set 4 | olafsvik
# Processing Record 10 of Set 4 | noumea
# Processing Record 11 of Set 4 | honiara
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | marsh harbour
# Processing Record 14 of Set 4 | lasa
# Processing Record 15 of Set 4 | murmashi
# Processing Record 16 of Set 4 | council bluffs
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | severo-yeniseyskiy
# Processing Record 19 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 20 of Set 4 | dom pedrito
# Processing Record 21 of Set 4 | chirongui
# Processing Record 22 of Set 4 | palmital
# Processing Record 23 of Set 4 | shimoda
# Processing Record 24 of Set 4 | tigre
# Processing Record 25 of Set 4 | bengkulu
# Processing Record 26 of Set 4 | cayenne
# Processing Record 27 of Set 4 | henties bay
# Processing Record 28 of Set 4 | asfi
# Processing Record 29 of Set 4 | kharan
# Processing Record 30 of Set 4 | tivaouane
# Processing Record 31 of Set 4 | voyvozh
# Processing Record 32 of Set 4 | leningradskiy
# Processing Record 33 of Set 4 | rundu
# Processing Record 34 of Set 4 | katangli
# Processing Record 35 of Set 4 | souillac
# Processing Record 36 of Set 4 | rocha
# Processing Record 37 of Set 4 | dalkola
# Processing Record 38 of Set 4 | nouadhibou
# Processing Record 39 of Set 4 | nanortalik
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | tamale
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 4 | inongo
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | goundam
# Processing Record 47 of Set 4 | sibolga
# Processing Record 48 of Set 4 | kurilsk
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | mackay
# Processing Record 1 of Set 5 | puerto escondido
# Processing Record 2 of Set 5 | sitka
# Processing Record 3 of Set 5 | svetlyy
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | hami
# Processing Record 8 of Set 5 | clyde river
# Processing Record 9 of Set 5 | peniche
# Processing Record 10 of Set 5 | chokurdakh
# Processing Record 11 of Set 5 | brae
# Processing Record 12 of Set 5 | hailar
# Processing Record 13 of Set 5 | kudahuvadhoo
# Processing Record 14 of Set 5 | fez
# Processing Record 15 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 16 of Set 5 | lerwick
# Processing Record 17 of Set 5 | maningrida
# Processing Record 18 of Set 5 | aranos
# Processing Record 19 of Set 5 | opunake
# Processing Record 20 of Set 5 | komsomolskiy
# Processing Record 21 of Set 5 | lebu
# Processing Record 22 of Set 5 | chara
# Processing Record 23 of Set 5 | dalianwan
# Processing Record 24 of Set 5 | north platte
# Processing Record 25 of Set 5 | zhangye
# Processing Record 26 of Set 5 | baruun-urt
# Processing Record 27 of Set 5 | porto walter
# Processing Record 28 of Set 5 | tahta
# Processing Record 29 of Set 5 | laguna
# Processing Record 30 of Set 5 | sarab
# Processing Record 31 of Set 5 | khandagayty
# Processing Record 32 of Set 5 | faribault
# Processing Record 33 of Set 5 | gasa
# Processing Record 34 of Set 5 | barabash
# Processing Record 35 of Set 5 | beringovskiy
# Processing Record 36 of Set 5 | umm kaddadah
# Processing Record 37 of Set 5 | severo-kurilsk
# Processing Record 38 of Set 5 | port macquarie
# Processing Record 39 of Set 5 | grua
# Processing Record 40 of Set 5 | kruisfontein
# Processing Record 41 of Set 5 | morros
# Processing Record 42 of Set 5 | richards bay
# Processing Record 43 of Set 5 | harda
# Processing Record 44 of Set 5 | provost
# Processing Record 45 of Set 5 | sant feliu de guixols
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | erzin
# Processing Record 49 of Set 5 | sept-iles
# Processing Record 50 of Set 5 | wielun
# Processing Record 1 of Set 6 | kuytun
# Processing Record 2 of Set 6 | iranshahr
# Processing Record 3 of Set 6 | husavik
# Processing Record 4 of Set 6 | alihe
# Processing Record 5 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 6 of Set 6 | sinnamary
# Processing Record 7 of Set 6 | liverpool
# Processing Record 8 of Set 6 | birao
# Processing Record 9 of Set 6 | raudeberg
# Processing Record 10 of Set 6 | kita
# Processing Record 11 of Set 6 | ngunguru
# Processing Record 12 of Set 6 | yenagoa
# Processing Record 13 of Set 6 | conceicao do araguaia
# Processing Record 14 of Set 6 | bereda
# Processing Record 15 of Set 6 | cockburn town
# Processing Record 16 of Set 6 | nassau
# Processing Record 17 of Set 6 | cidreira
# Processing Record 18 of Set 6 | honningsvag
# Processing Record 19 of Set 6 | gorontalo
# Processing Record 20 of Set 6 | emerald
# Processing Record 21 of Set 6 | villa carlos paz
# Processing Record 22 of Set 6 | winnemucca
# Processing Record 23 of Set 6 | vytegra
# Processing Record 24 of Set 6 | aksarka
# Processing Record 25 of Set 6 | cairns
# Processing Record 26 of Set 6 | qaqortoq
# Processing Record 27 of Set 6 | klaksvik
# Processing Record 28 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | isla mujeres
# Processing Record 30 of Set 6 | basyanovskiy
# City not found. Skipping...
# Processing Record 31 of Set 6 | caravelas
# Processing Record 32 of Set 6 | sehithwa
# Processing Record 33 of Set 6 | talah
# City not found. Skipping...
# Processing Record 34 of Set 6 | valdivia
# Processing Record 35 of Set 6 | breves
# Processing Record 36 of Set 6 | bambous virieux
# Processing Record 37 of Set 6 | vredendal
# Processing Record 38 of Set 6 | praia da vitoria
# Processing Record 39 of Set 6 | carnarvon
# Processing Record 40 of Set 6 | black diamond
# Processing Record 41 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 6 | antofagasta
# Processing Record 43 of Set 6 | luganville
# Processing Record 44 of Set 6 | lityn
# Processing Record 45 of Set 6 | vao
# Processing Record 46 of Set 6 | baihar
# Processing Record 47 of Set 6 | korla
# Processing Record 48 of Set 6 | shumikha
# Processing Record 49 of Set 6 | altamira
# Processing Record 50 of Set 6 | becerril
# Processing Record 1 of Set 7 | alice springs
# Processing Record 2 of Set 7 | caratinga
# Processing Record 3 of Set 7 | andrelandia
# Processing Record 4 of Set 7 | lorengau
# Processing Record 5 of Set 7 | itoman
# Processing Record 6 of Set 7 | manicore
# Processing Record 7 of Set 7 | geraldton
# Processing Record 8 of Set 7 | laguna de perlas
# Processing Record 9 of Set 7 | saiha
# Processing Record 10 of Set 7 | abapo
# Processing Record 11 of Set 7 | tiznit
# Processing Record 12 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 7 | necochea
# Processing Record 14 of Set 7 | benguela
# Processing Record 15 of Set 7 | ariquemes
# Processing Record 16 of Set 7 | beian
# Processing Record 17 of Set 7 | ginda
# Processing Record 18 of Set 7 | sisimiut
# Processing Record 19 of Set 7 | kalmunai
# Processing Record 20 of Set 7 | santa ana
# Processing Record 21 of Set 7 | airai
# Processing Record 22 of Set 7 | beaupre
# Processing Record 23 of Set 7 | vanimo
# Processing Record 24 of Set 7 | georgiyevka
# Processing Record 25 of Set 7 | porto belo
# Processing Record 26 of Set 7 | saint-joseph
# Processing Record 27 of Set 7 | scarborough
# Processing Record 28 of Set 7 | sao fidelis
# Processing Record 29 of Set 7 | lebowakgomo
# Processing Record 30 of Set 7 | vardo
# Processing Record 31 of Set 7 | grindavik
# Processing Record 32 of Set 7 | banjar
# Processing Record 33 of Set 7 | guymon
# Processing Record 34 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 7 | gebre guracha
# Processing Record 36 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 7 | sabya
# Processing Record 38 of Set 7 | lithakia
# Processing Record 39 of Set 7 | norrtalje
# Processing Record 40 of Set 7 | seydisehir
# Processing Record 41 of Set 7 | piltene
# Processing Record 42 of Set 7 | narsaq
# Processing Record 43 of Set 7 | najran
# Processing Record 44 of Set 7 | maputo
# Processing Record 45 of Set 7 | axim
# Processing Record 46 of Set 7 | kyenjojo
# Processing Record 47 of Set 7 | waitati
# Processing Record 48 of Set 7 | xiongshi
# City not found. Skipping...
# Processing Record 49 of Set 7 | fengcheng
# Processing Record 50 of Set 7 | natal
# Processing Record 1 of Set 8 | buritizeiro
# Processing Record 2 of Set 8 | srednekolymsk
# Processing Record 3 of Set 8 | palana
# Processing Record 4 of Set 8 | santiago del estero
# Processing Record 5 of Set 8 | alcaniz
# Processing Record 6 of Set 8 | qurayyat
# Processing Record 7 of Set 8 | moberly
# Processing Record 8 of Set 8 | phonhong
# Processing Record 9 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 8 | oriximina
# Processing Record 11 of Set 8 | tucupita
# Processing Record 12 of Set 8 | balkanabat
# Processing Record 13 of Set 8 | tautira
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | tuktoyaktuk
# Processing Record 16 of Set 8 | gat
# Processing Record 17 of Set 8 | san policarpo
# Processing Record 18 of Set 8 | tucuma
# Processing Record 19 of Set 8 | roma
# Processing Record 20 of Set 8 | itaqui
# Processing Record 21 of Set 8 | mahebourg
# Processing Record 22 of Set 8 | yar-sale
# Processing Record 23 of Set 8 | kutum
# Processing Record 24 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 8 | goderich
# Processing Record 26 of Set 8 | asau
# Processing Record 27 of Set 8 | tuatapere
# Processing Record 28 of Set 8 | loreto
# Processing Record 29 of Set 8 | kikwit
# Processing Record 30 of Set 8 | purpe
# Processing Record 31 of Set 8 | viedma
# Processing Record 32 of Set 8 | fasa
# Processing Record 33 of Set 8 | uvat
# Processing Record 34 of Set 8 | ossora
# Processing Record 35 of Set 8 | grand-santi
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | tirano
# Processing Record 38 of Set 8 | mandalgovi
# Processing Record 39 of Set 8 | zarubino
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | moron
# Processing Record 42 of Set 8 | bosanski novi
# Processing Record 43 of Set 8 | bathsheba
# Processing Record 44 of Set 8 | poum
# Processing Record 45 of Set 8 | esmeraldas
# Processing Record 46 of Set 8 | mehriz
# Processing Record 47 of Set 8 | vila
# Processing Record 48 of Set 8 | povenets
# Processing Record 49 of Set 8 | buenos aires
# Processing Record 50 of Set 8 | gizo
# Processing Record 1 of Set 9 | yalchiki
# City not found. Skipping...
# Processing Record 2 of Set 9 | castellarano
# Processing Record 3 of Set 9 | saldanha
# Processing Record 4 of Set 9 | hohhot
# Processing Record 5 of Set 9 | cooma
# Processing Record 6 of Set 9 | treinta y tres
# Processing Record 7 of Set 9 | assiniboia
# Processing Record 8 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 9 | boma
# Processing Record 10 of Set 9 | matara
# Processing Record 11 of Set 9 | doha
# Processing Record 12 of Set 9 | yulara
# Processing Record 13 of Set 9 | ikole
# City not found. Skipping...
# Processing Record 14 of Set 9 | palora
# Processing Record 15 of Set 9 | aden
# Processing Record 16 of Set 9 | kaifeng
# Processing Record 17 of Set 9 | labuhan
# Processing Record 18 of Set 9 | mamlyutka
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | sambava
# Processing Record 21 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | dauphin
# Processing Record 23 of Set 9 | lavrentiya
# Processing Record 24 of Set 9 | guerrero negro
# Processing Record 25 of Set 9 | don sak
# Processing Record 26 of Set 9 | grand gaube
# Processing Record 27 of Set 9 | burnie
# Processing Record 28 of Set 9 | stornoway
# Processing Record 29 of Set 9 | hanko
# Processing Record 30 of Set 9 | coquimbo
# Processing Record 31 of Set 9 | bonavista
# Processing Record 32 of Set 9 | parati
# Processing Record 33 of Set 9 | great yarmouth
# Processing Record 34 of Set 9 | johor bahru
# Processing Record 35 of Set 9 | saint thomas
# Processing Record 36 of Set 9 | mehamn
# Processing Record 37 of Set 9 | port hueneme
# Processing Record 38 of Set 9 | pare
# Processing Record 39 of Set 9 | moree
# Processing Record 40 of Set 9 | isangel
# Processing Record 41 of Set 9 | bubaque
# Processing Record 42 of Set 9 | strezhevoy
# Processing Record 43 of Set 9 | gigmoto
# Processing Record 44 of Set 9 | cabrero
# Processing Record 45 of Set 9 | mount isa
# Processing Record 46 of Set 9 | bilibino
# Processing Record 47 of Set 9 | ahuimanu
# Processing Record 48 of Set 9 | karachi
# Processing Record 49 of Set 9 | takoradi
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | goma
# Processing Record 2 of Set 10 | burica
# City not found. Skipping...
# Processing Record 3 of Set 10 | burgeo
# Processing Record 4 of Set 10 | danshui
# Processing Record 5 of Set 10 | taksimo
# Processing Record 6 of Set 10 | srivardhan
# Processing Record 7 of Set 10 | corner brook
# Processing Record 8 of Set 10 | malanje
# Processing Record 9 of Set 10 | wajir
# Processing Record 10 of Set 10 | san andres
# Processing Record 11 of Set 10 | yerbogachen
# Processing Record 12 of Set 10 | tsarychanka
# Processing Record 13 of Set 10 | khandyga
# Processing Record 14 of Set 10 | yahotyn
# Processing Record 15 of Set 10 | besikduzu
# Processing Record 16 of Set 10 | ciudad bolivar
# Processing Record 17 of Set 10 | lagoa vermelha
# Processing Record 18 of Set 10 | skibbereen
# Processing Record 19 of Set 10 | northam
# Processing Record 20 of Set 10 | cross lanes
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | kahului
# Processing Record 23 of Set 10 | micheweni
# Processing Record 24 of Set 10 | nowy targ
# Processing Record 25 of Set 10 | lahaina
# Processing Record 26 of Set 10 | dubai
# Processing Record 27 of Set 10 | oksfjord
# Processing Record 28 of Set 10 | lavras
# Processing Record 29 of Set 10 | peace river
# Processing Record 30 of Set 10 | gao
# Processing Record 31 of Set 10 | piracuruca
# Processing Record 32 of Set 10 | dingle
# Processing Record 33 of Set 10 | rio gallegos
# Processing Record 34 of Set 10 | russell
# Processing Record 35 of Set 10 | pirapora
# Processing Record 36 of Set 10 | hambantota
# Processing Record 37 of Set 10 | half moon bay
# Processing Record 38 of Set 10 | tabuk
# Processing Record 39 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 40 of Set 10 | makakilo city
# Processing Record 41 of Set 10 | klyuchi
# Processing Record 42 of Set 10 | ventspils
# Processing Record 43 of Set 10 | marawi
# Processing Record 44 of Set 10 | mindyak
# Processing Record 45 of Set 10 | eyl
# Processing Record 46 of Set 10 | logrono
# Processing Record 47 of Set 10 | bastrop
# Processing Record 48 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 10 | borogontsy
# Processing Record 50 of Set 10 | padang
# Processing Record 1 of Set 11 | codrington
# Processing Record 2 of Set 11 | pemangkat
# Processing Record 3 of Set 11 | longyearbyen
# Processing Record 4 of Set 11 | opuwo
# Processing Record 5 of Set 11 | chapais
# Processing Record 6 of Set 11 | sao felix do xingu
# Processing Record 7 of Set 11 | victoria
# Processing Record 8 of Set 11 | laurel
# Processing Record 9 of Set 11 | khorixas
# Processing Record 10 of Set 11 | nantucket
# Processing Record 11 of Set 11 | tunceli
# Processing Record 12 of Set 11 | oyo
# Processing Record 13 of Set 11 | yanam
# Processing Record 14 of Set 11 | progreso
# Processing Record 15 of Set 11 | iturama
# Processing Record 16 of Set 11 | la ronge
# Processing Record 17 of Set 11 | seoul
# Processing Record 18 of Set 11 | altay
# Processing Record 19 of Set 11 | paita
# Processing Record 20 of Set 11 | flinders
# Processing Record 21 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 11 | riyadh
# Processing Record 23 of Set 11 | phan thiet
# Processing Record 24 of Set 11 | yaan
# Processing Record 25 of Set 11 | valparaiso
# Processing Record 26 of Set 11 | tripoli
# Processing Record 27 of Set 11 | awjilah
# Processing Record 28 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 11 | qostanay
# Processing Record 30 of Set 11 | hamilton
# Processing Record 31 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 11 | qitaihe
# Processing Record 33 of Set 11 | razdolnoye
# Processing Record 34 of Set 11 | tocopilla
# Processing Record 35 of Set 11 | nabire
# Processing Record 36 of Set 11 | yingshang
# City not found. Skipping...
# Processing Record 37 of Set 11 | huinan
# Processing Record 38 of Set 11 | alyangula
# Processing Record 39 of Set 11 | dosso
# Processing Record 40 of Set 11 | barra patuca
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | odweyne
# Processing Record 43 of Set 11 | larsnes
# Processing Record 44 of Set 11 | taltal
# Processing Record 45 of Set 11 | keetmanshoop
# Processing Record 46 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 11 | montepuez
# Processing Record 48 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 11 | qui nhon
# Processing Record 50 of Set 11 | carbonia
# Processing Record 1 of Set 12 | erenhot
# Processing Record 2 of Set 12 | mushie
# Processing Record 3 of Set 12 | balikpapan
# Processing Record 4 of Set 12 | abnub
# Processing Record 5 of Set 12 | bandar-e lengeh
# Processing Record 6 of Set 12 | paamiut
# Processing Record 7 of Set 12 | aras
# Processing Record 8 of Set 12 | inegol
# Processing Record 9 of Set 12 | ostrovnoy
# Processing Record 10 of Set 12 | salamiyah
# Processing Record 11 of Set 12 | alta gracia
# Processing Record 12 of Set 12 | forestville
# Processing Record 13 of Set 12 | nakskov
# Processing Record 14 of Set 12 | betioky
# Processing Record 15 of Set 12 | ayagoz
# Processing Record 16 of Set 12 | simpang
# Processing Record 17 of Set 12 | lower hutt
# Processing Record 18 of Set 12 | campbell river
# Processing Record 19 of Set 12 | lampazos de naranjo
# Processing Record 20 of Set 12 | muyezerskiy
# Processing Record 21 of Set 12 | peleduy
# Processing Record 22 of Set 12 | bonthe
# Processing Record 23 of Set 12 | roald
# Processing Record 24 of Set 12 | ulladulla
# Processing Record 25 of Set 12 | aklavik
# Processing Record 26 of Set 12 | mkushi
# Processing Record 27 of Set 12 | maraba
# Processing Record 28 of Set 12 | narasaraopet
# Processing Record 29 of Set 12 | wamba
# Processing Record 30 of Set 12 | panzhihua
# Processing Record 31 of Set 12 | zhigalovo
# Processing Record 32 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 12 | cintalapa
# Processing Record 34 of Set 12 | auki
# Processing Record 35 of Set 12 | sobolevo
# Processing Record 36 of Set 12 | barabai
# Processing Record 37 of Set 12 | irbil
# Processing Record 38 of Set 12 | jambi
# Processing Record 39 of Set 12 | taoudenni
# Processing Record 40 of Set 12 | maceio
# Processing Record 41 of Set 12 | pacaembu
# Processing Record 42 of Set 12 | bandarbeyla
# Processing Record 43 of Set 12 | omboue
# Processing Record 44 of Set 12 | doka
# Processing Record 45 of Set 12 | galgani
# City not found. Skipping...
# Processing Record 46 of Set 12 | znamenskoye
# Processing Record 47 of Set 12 | impfondo
# Processing Record 48 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 12 | saint-georges
# Processing Record 50 of Set 12 | houma
# Processing Record 1 of Set 13 | macau
# Processing Record 2 of Set 13 | boueni
# Processing Record 3 of Set 13 | flin flon
# Processing Record 4 of Set 13 | tabou
# Processing Record 5 of Set 13 | xining
# Processing Record 6 of Set 13 | bhuj
# Processing Record 7 of Set 13 | yershichi
# Processing Record 8 of Set 13 | rionero in vulture
# Processing Record 9 of Set 13 | itarema
# Processing Record 10 of Set 13 | storforshei
# Processing Record 11 of Set 13 | panama city
# Processing Record 12 of Set 13 | inverell
# Processing Record 13 of Set 13 | san ramon
# Processing Record 14 of Set 13 | chute-aux-outardes
# Processing Record 15 of Set 13 | dingzhou
# Processing Record 16 of Set 13 | sur
# Processing Record 17 of Set 13 | asti
# Processing Record 18 of Set 13 | ayan
# Processing Record 19 of Set 13 | kargopol
# Processing Record 20 of Set 13 | kashi
# Processing Record 21 of Set 13 | el faiyum
# City not found. Skipping...
# Processing Record 22 of Set 13 | laki
# Processing Record 23 of Set 13 | solnechnyy
# Processing Record 24 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 25 of Set 13 | fort collins
# Processing Record 26 of Set 13 | la libertad
# Processing Record 27 of Set 13 | taitung
# Processing Record 28 of Set 13 | george town
# Processing Record 29 of Set 13 | wajima
# Processing Record 30 of Set 13 | oliver
# Processing Record 31 of Set 13 | atibaia
# Processing Record 32 of Set 13 | vestmannaeyjar
# Processing Record 33 of Set 13 | sao joao da barra
# Processing Record 34 of Set 13 | neuquen
# Processing Record 35 of Set 13 | khani
# Processing Record 36 of Set 13 | keuruu
# Processing Record 37 of Set 13 | salinopolis
# Processing Record 38 of Set 13 | narrabri
# Processing Record 39 of Set 13 | banmo
# City not found. Skipping...
# Processing Record 40 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 13 | wanning
# Processing Record 42 of Set 13 | ganserndorf
# Processing Record 43 of Set 13 | abu kamal
# Processing Record 44 of Set 13 | akom
# Processing Record 45 of Set 13 | nadym
# Processing Record 46 of Set 13 | guaruja
# Processing Record 47 of Set 13 | sao filipe
# Processing Record 48 of Set 13 | sao tome
# Processing Record 49 of Set 13 | yeppoon
# Processing Record 50 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 1 of Set 14 | verdalsora
# City not found. Skipping...
# Processing Record 2 of Set 14 | kushiro
# Processing Record 3 of Set 14 | beyneu
# Processing Record 4 of Set 14 | bolotnoye
# Processing Record 5 of Set 14 | araouane
# Processing Record 6 of Set 14 | nioro
# Processing Record 7 of Set 14 | mozarlandia
# Processing Record 8 of Set 14 | sonoita
# Processing Record 9 of Set 14 | tutoia
# Processing Record 10 of Set 14 | adrar
# Processing Record 11 of Set 14 | fort nelson
# Processing Record 12 of Set 14 | coihaique
# Processing Record 13 of Set 14 | katherine
# Processing Record 14 of Set 14 | the valley
# Processing Record 15 of Set 14 | chengde
# Processing Record 16 of Set 14 | isla vista
# Processing Record 17 of Set 14 | kysyl-syr
# Processing Record 18 of Set 14 | tianpeng
# Processing Record 19 of Set 14 | wilson
# Processing Record 20 of Set 14 | boqueirao
# Processing Record 21 of Set 14 | aguimes
# Processing Record 22 of Set 14 | kerman
# Processing Record 23 of Set 14 | palmira
# Processing Record 24 of Set 14 | walvis bay
# Processing Record 25 of Set 14 | batagay-alyta
# Processing Record 26 of Set 14 | nizwa
# Processing Record 27 of Set 14 | kirkenes
# Processing Record 28 of Set 14 | zhoucheng
# Processing Record 29 of Set 14 | rive-de-gier
# Processing Record 30 of Set 14 | cabedelo
# Processing Record 31 of Set 14 | tiarei
# Processing Record 32 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 14 | gort
# Processing Record 34 of Set 14 | bodo
# Processing Record 35 of Set 14 | netarhat
# Processing Record 36 of Set 14 | brigantine
# Processing Record 37 of Set 14 | oer-erkenschwick
# Processing Record 38 of Set 14 | constitucion
# Processing Record 39 of Set 14 | camopi
# Processing Record 40 of Set 14 | tromso
# Processing Record 41 of Set 14 | kwinana
# Processing Record 42 of Set 14 | rio verde de mato grosso
# Processing Record 43 of Set 14 | krasnogorskoye
# Processing Record 44 of Set 14 | ketchikan
# Processing Record 45 of Set 14 | ouesso
# Processing Record 46 of Set 14 | labrea
# Processing Record 47 of Set 14 | zdvinsk
# Processing Record 48 of Set 14 | manokwari
# Processing Record 49 of Set 14 | carson city
# Processing Record 50 of Set 14 | danjiangkou
# Processing Record 1 of Set 15 | gweta
# Processing Record 2 of Set 15 | dongying
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | praia
# Processing Record 5 of Set 15 | irece
# Processing Record 6 of Set 15 | chivilcoy
# Processing Record 7 of Set 15 | kasama
# Processing Record 8 of Set 15 | terrace
# Processing Record 9 of Set 15 | turje
# Processing Record 10 of Set 15 | puerto quijarro
# Processing Record 11 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 15 | ramhormoz
# Processing Record 13 of Set 15 | maryborough
# Processing Record 14 of Set 15 | angoche
# Processing Record 15 of Set 15 | uinskoye
# Processing Record 16 of Set 15 | healdsburg
# Processing Record 17 of Set 15 | redding
# Processing Record 18 of Set 15 | jacqueville
# Processing Record 19 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 15 | manutuke
# Processing Record 21 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 15 | otukpo
# Processing Record 23 of Set 15 | saveh
# Processing Record 24 of Set 15 | jardim
# Processing Record 25 of Set 15 | manali
# Processing Record 26 of Set 15 | fairborn
# Processing Record 27 of Set 15 | ibi
# Processing Record 28 of Set 15 | kentau
# Processing Record 29 of Set 15 | verkhnevilyuysk
# Processing Record 30 of Set 15 | jiayuguan
# Processing Record 31 of Set 15 | touros
# Processing Record 32 of Set 15 | harper
# Processing Record 33 of Set 15 | sorong
# Processing Record 34 of Set 15 | dongsheng
# Processing Record 35 of Set 15 | vila velha
# Processing Record 36 of Set 15 | verkhnyaya toyma
# Processing Record 37 of Set 15 | mulanje
# Processing Record 38 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 39 of Set 15 | grenada
# Processing Record 40 of Set 15 | muros
# Processing Record 41 of Set 15 | yamada
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
#Adding the data to a new DataFrame
weatherpy_df=pd.DataFrame(city_data)
weatherpy_df.head()
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Faanui      PF -16.4833 -151.7500     81.28        70           1
# 1  Port Elizabeth      ZA -33.9180   25.5701     66.09        71          99
# 2    Jacareacanga      BR  -6.2222  -57.7528     75.00        88         100
# 3        Vanavara      RU  60.3400  102.2797     11.50        93         100
# 4           Alofi      NU -19.0595 -169.9187     75.09        94         100
#
#    Wind Speed          Current Description
# 0       15.12                    clear sky
# 1       13.98              overcast clouds
# 2        0.60              overcast clouds
# 3        8.90                   light snow
# 4        5.75  light intensity shower rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
weatherpy_df.to_csv(output_data_file, index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\N01405~1\AppData\Local\Temp/ipykernel_15780/1138990262.py in <module>
#       1 # Create the output file (CSV).
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
# ----> 3 weatherpy_df.to_csv(output_data_file, index_label='City_ID')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
